# %% [markdown]
# <a href="https://colab.research.google.com/github/6ixthxense/Toolboox/blob/main/toolboox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
import pandas as pd
import pandasql
res = pd.read_csv('toolboxxxx - การตอบแบบฟอร์ม 1.csv')
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.1.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.22)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.6.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.5.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26781 sha256=e2acdc7582c3b796b48b1095e775d4118113af031402243989a611be98dff907
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
result_df= pd.DataFrame(res)
result_df.shape
# Out:
# (63, 9)

# %%
result_df.columns
# Out:
# Index(['ประทับเวลา', 'เพศ', 'ช่วงอายุ', 'โรคประจำตัว',
#        'โซนสีของจัดหวัดที่อยู่ อิงตามข้อมูล ณ วันที่ 3/8/2564',
#        'ท่านได้รับวัคซีนหรือยัง', 'ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด',
#        'ชนิดของวัคซีนที่เชื่อมั่น', 'เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ'],
#       dtype='object')

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   ประทับเวลา                                             63 non-null     object
#  1   เพศ                                                    63 non-null     object
#  2   ช่วงอายุ                                               63 non-null     object
#  3   โรคประจำตัว                                            63 non-null     object
#  4   โซนสีของจัดหวัดที่อยู่ อิงตามข้อมูล ณ วันที่ 3/8/2564  62 non-null     object
#  5   ท่านได้รับวัคซีนหรือยัง                                63 non-null     object
#  6   ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด                63 non-null     object
#  7   ชนิดของวัคซีนที่เชื่อมั่น                              63 non-null     object
#  8   เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ                  30 non-null     object
# dtypes: object(9)
# memory usage: 4.6+ KB

# %%
result_df.head(50)
# Out:
#              ประทับเวลา  ...              เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ
# 0   21/8/2021, 19:53:08  ...                                                 ดี
# 1   21/8/2021, 19:53:18  ...                                                  -
# 2   21/8/2021, 19:54:38  ...                                          เชื่อมั่น
# 3   21/8/2021, 19:54:52  ...                                                NaN
# 4   21/8/2021, 19:56:08  ...                                                NaN
# 5   21/8/2021, 19:57:04  ...                                                NaN
# 6   21/8/2021, 19:58:07  ...                                          คุณภาพอ่ะ
# 7   21/8/2021, 19:58:53  ...                                       ก็ Pfizer ดี
# 8   21/8/2021, 19:59:26  ...                       ไม่ใช่ซีโนแวคอะ มั่นใจหมดเลย
# 9   21/8/2021, 19:59:47  ...                   Johnson and Johnson ฉีดเข็มเดียว
# 10  21/8/2021, 20:00:34  ...                                                NaN
# 11  21/8/2021, 20:00:37  ...                                                NaN
# 12  21/8/2021, 20:01:14  ...                                      ประสิทธิภาพดี
# 13  21/8/2021, 20:01:42  ...                                                  -
# 14  21/8/2021, 20:02:02  ...                                                NaN
# 15  21/8/2021, 20:04:55  ...                                                  -
# 16  21/8/2021, 20:07:52  ...     เชื่อมั่นในแบรนด์มีคุณภาพและการรับรองที่แน่นอน
# 17  21/8/2021, 20:10:14  ...                                                  -
# 18  21/8/2021, 20:11:07  ...                                                NaN
# 19  21/8/2021, 20:12:48  ...                                                NaN
# 20  21/8/2021, 20:17:27  ...                                                NaN
# 21  21/8/2021, 20:17:32  ...                                                NaN
# 22  21/8/2021, 20:17:36  ...                                                NaN
# 23  21/8/2021, 20:17:54  ...                               มีภูมิคุ้มกันมากกว่า
# 24  21/8/2021, 20:20:06  ...                                                NaN
# 25  21/8/2021, 20:26:58  ...                                                NaN
# 26  21/8/2021, 20:32:37  ...                                อันตราความน่าจะเป็น
# 27  21/8/2021, 20:34:40  ...                                             ไม่รู้
# 28  21/8/2021, 20:37:35  ...                                                NaN
# 29  21/8/2021, 20:38:06  ...                        เป็นวัคซีนที่เฉพาะบุคคลนั้น
# 30  21/8/2021, 20:54:13  ...               คิดว่าน่าจะดีมากที่สุด ได้ผลดีที่สุด
# 31  21/8/2021, 20:59:06  ...  ดูจากประเทศที่เจริญแล้วที่เค้ามีวัคซีนดีๆ ช่วย...
# 32  21/8/2021, 20:59:08  ...  ศึกษาจากข่าวและเปรียบเทียบผลข้างเคียงของแต่ละป...
# 33  21/8/2021, 21:07:13  ...                                                NaN
# 34  21/8/2021, 22:03:13  ...                                              ไม่มี
# 35  21/8/2021, 22:03:42  ...                                                NaN
# 36  21/8/2021, 22:14:41  ...  ประสิทธิภาพในภูมิคุ้มกันแบบหมู่ อีกทั้งการทดลอ...
# 37  21/8/2021, 22:31:56  ...  งานวิจัยก็มีให้เห็นแล้ว ภาพประเทศอื่นที่ฉีดก็ม...
# 38  21/8/2021, 23:08:24  ...                                                  -
# 39  21/8/2021, 23:08:50  ...                                                  -
# 40  21/8/2021, 23:09:17  ...                                                 ดี
# 41  21/8/2021, 23:10:05  ...                                                  -
# 42  21/8/2021, 23:14:15  ...                                                NaN
# 43  21/8/2021, 23:15:30  ...                                                NaN
# 44  21/8/2021, 23:15:40  ...                                                NaN
# 45  21/8/2021, 23:16:09  ...                                                NaN
# 46  21/8/2021, 23:16:15  ...                                                NaN
# 47  21/8/2021, 23:17:05  ...                                                NaN
# 48  21/8/2021, 23:17:15  ...                                                NaN
# 49  21/8/2021, 23:17:31  ...                                                NaN
#
# [50 rows x 9 columns]

# %%
result_df.isnull().sum()
# Out:
# ประทับเวลา                                                0
# เพศ                                                       0
# ช่วงอายุ                                                  0
# โรคประจำตัว                                               0
# โซนสีของจัดหวัดที่อยู่ อิงตามข้อมูล ณ วันที่ 3/8/2564     1
# ท่านได้รับวัคซีนหรือยัง                                   0
# ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด                   0
# ชนิดของวัคซีนที่เชื่อมั่น                                 0
# เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ                    33
# dtype: int64

# %%
result_df.head(40)
# Out:
#              ประทับเวลา  ...              เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ
# 0   21/8/2021, 19:53:08  ...                                                 ดี
# 1   21/8/2021, 19:53:18  ...                                                  -
# 2   21/8/2021, 19:54:38  ...                                          เชื่อมั่น
# 3   21/8/2021, 19:54:52  ...                                                NaN
# 4   21/8/2021, 19:56:08  ...                                                NaN
# 5   21/8/2021, 19:57:04  ...                                                NaN
# 6   21/8/2021, 19:58:07  ...                                          คุณภาพอ่ะ
# 7   21/8/2021, 19:58:53  ...                                       ก็ Pfizer ดี
# 8   21/8/2021, 19:59:26  ...                       ไม่ใช่ซีโนแวคอะ มั่นใจหมดเลย
# 9   21/8/2021, 19:59:47  ...                   Johnson and Johnson ฉีดเข็มเดียว
# 10  21/8/2021, 20:00:34  ...                                                NaN
# 11  21/8/2021, 20:00:37  ...                                                NaN
# 12  21/8/2021, 20:01:14  ...                                      ประสิทธิภาพดี
# 13  21/8/2021, 20:01:42  ...                                                  -
# 14  21/8/2021, 20:02:02  ...                                                NaN
# 15  21/8/2021, 20:04:55  ...                                                  -
# 16  21/8/2021, 20:07:52  ...     เชื่อมั่นในแบรนด์มีคุณภาพและการรับรองที่แน่นอน
# 17  21/8/2021, 20:10:14  ...                                                  -
# 18  21/8/2021, 20:11:07  ...                                                NaN
# 19  21/8/2021, 20:12:48  ...                                                NaN
# 20  21/8/2021, 20:17:27  ...                                                NaN
# 21  21/8/2021, 20:17:32  ...                                                NaN
# 22  21/8/2021, 20:17:36  ...                                                NaN
# 23  21/8/2021, 20:17:54  ...                               มีภูมิคุ้มกันมากกว่า
# 24  21/8/2021, 20:20:06  ...                                                NaN
# 25  21/8/2021, 20:26:58  ...                                                NaN
# 26  21/8/2021, 20:32:37  ...                                อันตราความน่าจะเป็น
# 27  21/8/2021, 20:34:40  ...                                             ไม่รู้
# 28  21/8/2021, 20:37:35  ...                                                NaN
# 29  21/8/2021, 20:38:06  ...                        เป็นวัคซีนที่เฉพาะบุคคลนั้น
# 30  21/8/2021, 20:54:13  ...               คิดว่าน่าจะดีมากที่สุด ได้ผลดีที่สุด
# 31  21/8/2021, 20:59:06  ...  ดูจากประเทศที่เจริญแล้วที่เค้ามีวัคซีนดีๆ ช่วย...
# 32  21/8/2021, 20:59:08  ...  ศึกษาจากข่าวและเปรียบเทียบผลข้างเคียงของแต่ละป...
# 33  21/8/2021, 21:07:13  ...                                                NaN
# 34  21/8/2021, 22:03:13  ...                                              ไม่มี
# 35  21/8/2021, 22:03:42  ...                                                NaN
# 36  21/8/2021, 22:14:41  ...  ประสิทธิภาพในภูมิคุ้มกันแบบหมู่ อีกทั้งการทดลอ...
# 37  21/8/2021, 22:31:56  ...  งานวิจัยก็มีให้เห็นแล้ว ภาพประเทศอื่นที่ฉีดก็ม...
# 38  21/8/2021, 23:08:24  ...                                                  -
# 39  21/8/2021, 23:08:50  ...                                                  -
#
# [40 rows x 9 columns]

# %%
result_df['เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ'].unique()
# Out:
# array(['ดี', '-', 'เชื่อมั่น', nan, 'คุณภาพอ่ะ', 'ก็ Pfizer ดี',
#        'ไม่ใช่ซีโนแวคอะ มั่นใจหมดเลย', 'Johnson and Johnson ฉีดเข็มเดียว',
#        'ประสิทธิภาพดี', 'เชื่อมั่นในแบรนด์มีคุณภาพและการรับรองที่แน่นอน',
#        'มีภูมิคุ้มกันมากกว่า', 'อันตราความน่าจะเป็น', 'ไม่รู้',
#        'เป็นวัคซีนที่เฉพาะบุคคลนั้น',
#        'คิดว่าน่าจะดีมากที่สุด ได้ผลดีที่สุด',
#        'ดูจากประเทศที่เจริญแล้วที่เค้ามีวัคซีนดีๆ ช่วยลดการระบาดได้เยอะ ซึ่งไม่ใช่sinovac เลิกสั่งสักทีอิควัยย',
#        'ศึกษาจากข่าวและเปรียบเทียบผลข้างเคียงของแต่ละประเภท ซึ่งชนิดสารพันธุกรรมมีผลน้อยที่สุด',
#        'ไม่มี',
#        'ประสิทธิภาพในภูมิคุ้มกันแบบหมู่ อีกทั้งการทดลองของการใช้วัคซีนชนิดนี้ถือว่ามีความเหมาะสมที่สุด',
#        'งานวิจัยก็มีให้เห็นแล้ว ภาพประเทศอื่นที่ฉีดก็มีให้เห็น',
#        'มีการรับรอง', 'มีผลการรับรองที่น่าเชื่อถือ', 'วัคซีนดี',
#        'รู้สึกว่ามีผลการป้องกันต่อโควิดดี มีการวิจัยและผลออกมาน่าเชื่อถือมากที่สุด'],
#       dtype=object)

# %%
result_df['เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ'].replace({
        'ดี':'เชื่อมั่น',
        '-':'ไม่มี',
        'คุณภาพอ่ะ':'เชื่อมั่น',
        'ก็ Pfizer ดี':'เชื่อมั่น',
        'ไม่ใช่ซีโนแวคอะ มั่นใจหมดเลย':'เชื่อมั่น',
        'Johnson and Johnson ฉีดเข็มเดียว':'ไม่อยากฉีดหลายรอบ',
        'ประสิทธิภาพดี':'เชื่อมั่น',
        'เชื่อมั่นในแบรนด์มีคุณภาพและการรับรองที่แน่นอน':'เชื่อมั่น',
        'มีภูมิคุ้มกันมากกว่า':'เชื่อมั่น',
        'อันตราความน่าจะเป็น':'เชื่อมั่น',
        'เป็นวัคซีนที่เฉพาะบุคคลนั้น':'เชื่อมั่น',
        'คิดว่าน่าจะดีมากที่สุด ได้ผลดีที่สุด':'เชื่อมั่น',
        'ดูจากประเทศที่เจริญแล้วที่เค้ามีวัคซีนดีๆ ช่วยลดการระบาดได้เยอะ ซึ่งไม่ใช่sinovac เลิกสั่งสักทีอิควัยย':'เชื่อมั่น',
        'ศึกษาจากข่าวและเปรียบเทียบผลข้างเคียงของแต่ละประเภท ซึ่งชนิดสารพันธุกรรมมีผลน้อยที่สุด':'เชื่อมั่น',
        'ประสิทธิภาพในภูมิคุ้มกันแบบหมู่ อีกทั้งการทดลองของการใช้วัคซีนชนิดนี้ถือว่ามีความเหมาะสมที่สุด':'เชื่อมั่น',
        'มีการรับรอง':'เชื่อมั่น',
        'มีผลการรับรองที่น่าเชื่อถือ':'เชื่อมั่น',
        'วัคซีนดี':'เชื่อมั่น',
        'งานวิจัยก็มีให้เห็นแล้ว ภาพประเทศอื่นที่ฉีดก็มีให้เห็น':'เชื่อมั่น',
        'รู้สึกว่ามีผลการป้องกันต่อโควิดดี มีการวิจัยและผลออกมาน่าเชื่อถือมากที่สุด':'เชื่อมั่น',

    }, inplace=True)

# %%
result_df['เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ'].unique()
# Out:
# array(['เชื่อมั่น', 'ไม่มี', 'ไม่อยากฉีดหลายรอบ', 'ไม่รู้'], dtype=object)

# %%
result_df['เพศ'].unique()
# Out:
# array(['ชาย', 'LGBTQ+', 'หญิง'], dtype=object)

# %%
result_df['เพศ'].replace({
        'เกย์':'LGBTQ+',
        'LGBQ+':'LGBTQ+',
        'lgbtq':'LGBTQ+',
        'nonbinary':'LGBTQ+',
        'Lgbtq':'LGBTQ+',
    }, inplace=True)

# %%
result_df['ท่านได้รับวัคซีนหรือยัง'].unique()
# Out:
# array(['Sinovac', 'Astra Zeneca', 'ยังไม่ได้รับ', 'Sinopharm'],
#       dtype=object)

# %%
result_df['ท่านได้รับวัคซีนหรือยัง'].replace({
        'เข็มแรก Astra Zeneca เข็มสองไม่แน่ใจว่าได้อ่ะไร':'Astra Zeneca',
        'Sinavac':'Sinovac',
        'ผสม Sinovac + AZ':'Sinovac',
    }, inplace=True)

# %%
result_df['ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด'].unique()
# Out:
# array(['โทรทัศน์', 'Facebook', 'Twitter', 'Web Browser', 'IG', 'Line',
#        'Ig'], dtype=object)

# %%
result_df['ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด'].replace({
        'Ig':'IG',
    }, inplace=True)

# %%
result_df['เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ'].fillna('ไม่มี',inplace=True)

# %%
result_df= result_df.drop(41, axis=0)
result_df.reset_index(drop=True)
# Out:
#              ประทับเวลา  ...              เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ
# 0   21/8/2021, 19:53:08  ...                                          เชื่อมั่น
# 1   21/8/2021, 19:53:18  ...                                              ไม่มี
# 2   21/8/2021, 19:54:38  ...                                          เชื่อมั่น
# 3   21/8/2021, 19:54:52  ...                                              ไม่มี
# 4   21/8/2021, 19:56:08  ...                                              ไม่มี
# ..                  ...  ...                                                ...
# 57  21/8/2021, 23:20:05  ...                                              ไม่มี
# 58  21/8/2021, 23:20:32  ...                                              ไม่มี
# 59  21/8/2021, 23:20:33  ...                                              ไม่มี
# 60  22/8/2021, 18:25:47  ...                                              ไม่มี
# 61  22/8/2021, 18:48:23  ...  รู้สึกว่ามีผลการป้องกันต่อโควิดดี มีการวิจัยแล...
#
# [62 rows x 9 columns]

# %%
result_df.head(50)
# Out:
#              ประทับเวลา  ... เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ
# 0   21/8/2021, 19:53:08  ...                             เชื่อมั่น
# 1   21/8/2021, 19:53:18  ...                                 ไม่มี
# 2   21/8/2021, 19:54:38  ...                             เชื่อมั่น
# 3   21/8/2021, 19:54:52  ...                                 ไม่มี
# 4   21/8/2021, 19:56:08  ...                                 ไม่มี
# 5   21/8/2021, 19:57:04  ...                                 ไม่มี
# 6   21/8/2021, 19:58:07  ...                             เชื่อมั่น
# 7   21/8/2021, 19:58:53  ...                             เชื่อมั่น
# 8   21/8/2021, 19:59:26  ...                             เชื่อมั่น
# 9   21/8/2021, 19:59:47  ...                     ไม่อยากฉีดหลายรอบ
# 10  21/8/2021, 20:00:34  ...                                 ไม่มี
# 11  21/8/2021, 20:00:37  ...                                 ไม่มี
# 12  21/8/2021, 20:01:14  ...                             เชื่อมั่น
# 13  21/8/2021, 20:01:42  ...                                 ไม่มี
# 14  21/8/2021, 20:02:02  ...                                 ไม่มี
# 15  21/8/2021, 20:04:55  ...                                 ไม่มี
# 16  21/8/2021, 20:07:52  ...                             เชื่อมั่น
# 17  21/8/2021, 20:10:14  ...                                 ไม่มี
# 18  21/8/2021, 20:11:07  ...                                 ไม่มี
# 19  21/8/2021, 20:12:48  ...                                 ไม่มี
# 20  21/8/2021, 20:17:27  ...                                 ไม่มี
# 21  21/8/2021, 20:17:32  ...                                 ไม่มี
# 22  21/8/2021, 20:17:36  ...                                 ไม่มี
# 23  21/8/2021, 20:17:54  ...                             เชื่อมั่น
# 24  21/8/2021, 20:20:06  ...                                 ไม่มี
# 25  21/8/2021, 20:26:58  ...                                 ไม่มี
# 26  21/8/2021, 20:32:37  ...                             เชื่อมั่น
# 27  21/8/2021, 20:34:40  ...                                ไม่รู้
# 28  21/8/2021, 20:37:35  ...                                 ไม่มี
# 29  21/8/2021, 20:38:06  ...                             เชื่อมั่น
# 30  21/8/2021, 20:54:13  ...                             เชื่อมั่น
# 31  21/8/2021, 20:59:06  ...                             เชื่อมั่น
# 32  21/8/2021, 20:59:08  ...                             เชื่อมั่น
# 33  21/8/2021, 21:07:13  ...                                 ไม่มี
# 34  21/8/2021, 22:03:13  ...                                 ไม่มี
# 35  21/8/2021, 22:03:42  ...                                 ไม่มี
# 36  21/8/2021, 22:14:41  ...                             เชื่อมั่น
# 37  21/8/2021, 22:31:56  ...                             เชื่อมั่น
# 38  21/8/2021, 23:08:24  ...                                 ไม่มี
# 39  21/8/2021, 23:08:50  ...                                 ไม่มี
# 40  21/8/2021, 23:09:17  ...                             เชื่อมั่น
# 42  21/8/2021, 23:14:15  ...                                 ไม่มี
# 43  21/8/2021, 23:15:30  ...                                 ไม่มี
# 44  21/8/2021, 23:15:40  ...                                 ไม่มี
# 45  21/8/2021, 23:16:09  ...                                 ไม่มี
# 46  21/8/2021, 23:16:15  ...                                 ไม่มี
# 47  21/8/2021, 23:17:05  ...                                 ไม่มี
# 48  21/8/2021, 23:17:15  ...                                 ไม่มี
# 49  21/8/2021, 23:17:31  ...                                 ไม่มี
# 50  21/8/2021, 23:17:42  ...                                 ไม่มี
#
# [50 rows x 9 columns]

# %%
result_df.isnull().sum()
# Out:
# ประทับเวลา                                               0
# เพศ                                                      0
# ช่วงอายุ                                                 0
# โรคประจำตัว                                              0
# โซนสีของจัดหวัดที่อยู่ อิงตามข้อมูล ณ วันที่ 3/8/2564    0
# ท่านได้รับวัคซีนหรือยัง                                  0
# ติดตามข้อมูลข่าวสาร Covid-19 จากแหล่งใด                  0
# ชนิดของวัคซีนที่เชื่อมั่น                                0
# เหตุผลที่เชื่อมั่นในวัคซีนประเภทนั้นๆ                    0
# dtype: int64

# %%
result_df.to_csv('Toolbo.csv')
